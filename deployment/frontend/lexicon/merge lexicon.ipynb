# %%
import pandas as pd

# %%
slang = pd.read_csv('slang ke semi baku.csv')
baku = pd.read_csv('slang ke baku.csv')

# %%
slang = slang[['slang','formal']]

# %%
slang
# Out:
#                  slang      formal
# 0                22nya  dua-duanya
# 1                22nya  dua-duanya
# 2           aaaaaaakkk          ah
# 3            aaaaahhhh          ah
# 4      aaaammmiiiinnnn        amin
# ...                ...         ...
# 14992                z        saja
# 14993               za        saja
# 14994               za        saja
# 14995               za        saja
# 14996             zama       zaman
#
# [14997 rows x 2 columns]

# %%
baku.head()
# Out:
#     slang       baku
# 0       @         di
# 1     7an     tujuan
# 2  ababil  abg labil
# 3    abis      habis
# 4     acc     accord

# %%
std_word_replace = {}
for i, row in enumerate(baku['slang']):
    std_word_replace[row] = baku['baku'].iloc[i]

# %%
slang_replace = {}
for i, row in enumerate(slang['slang']):
    slang_replace[row] = slang['formal'].iloc[i]

# %%
std_word_replace
# Out:
# {'@': 'di',
#  '7an': 'tujuan',
#  'ababil': 'abg labil',
#  'abis': 'habis',
#  'acc': 'accord',
#  'accord': 'sesuai',
#  'ad': 'ada',
#  'adlah': 'adalah',
#  'adlh': 'adalah',
#  'adoh': 'aduh',
#  'afaik': 'as far as i know',
#  'aha': 'tertawa',
#  'ahaha': 'haha',
#  'ahiok': 'ahok',
#  'ahokncc': 'ahok',
#  'aing': 'saya',
#  'aj': 'saja',
#  'aja': 'saja',
#  'ajep-ajep': 'dunia gemerlap',
#  'ajj': 'saja',
#  'ak': 'saya',
#  'aka': 'dikenal juga sebagai',
#  'akhirx': 'akhirnya',
#  'akika': 'aku',
#  'akko': 'aku',
#  'akkoh': 'aku',
#  'akku': 'aku',
#  'akuwh': 'aku',
#  'akyu': 'aku',
#  'alay': 'norak',
#  'aljasa': 'asal jadi saja',
#  'almaidahyg': 'almaidah',
#  'alow': 'halo',
#  'ama': 'sama',
#  'ambilin': 'ambilkan',
#  'ambl': 'ambil',
#  'amerik': 'amarika',
#  'analisise': 'analisis',
#  'ancur': 'hancur',
#  'angis': 'nangis',
#  'anjay': 'anjing',
#  'anjir': 'anjing',
#  'anjrit': 'anjing',
#  'ank': 'anak',
#  'anter': 'antar',
#  'ap': 'apa',
# ...

# %%
bakus = []
for i, kata in enumerate(slang['slang']):
    try:
        bakus.append(std_word_replace[kata])
    except:
        bakus.append(slang_replace[kata])

# %%
slang['baku'] = bakus

# %%
bakus2 = []
for i, kata in enumerate(slang['baku']):
    try:
        bakus2.append(std_word_replace[kata])
    except:
        bakus2.append(kata)

# %%
slang['baku final'] = bakus2

# %%
slang.drop_duplicates(subset='slang', keep='first', inplace=True)
slang
# Out:
#                  slang      formal        baku  baku final
# 0                22nya  dua-duanya  dua-duanya  dua-duanya
# 2           aaaaaaakkk          ah          ah          ah
# 3            aaaaahhhh          ah          ah          ah
# 4      aaaammmiiiinnnn        amin        amin        amin
# 5                aaahh          ah          ah          ah
# ...                ...         ...         ...         ...
# 14986              yya          ya          ya         iya
# 14989            yyaaa          ya          ya         iya
# 14990                z        saja        saja        saja
# 14993               za        saja        saja        saja
# 14996             zama       zaman       zaman       zaman
#
# [4329 rows x 4 columns]

# %%
slang.to_csv('baku.csv', index=False)

# %%
drop_baku = pd.read_csv('baku.csv')
drop_baku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5649 entries, 0 to 5648
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   slang   5649 non-null   object
#  1   baku    5648 non-null   object
#  2   source  5649 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 132.5+ KB

# %%
drop_baku.drop_duplicates(subset='slang', keep='first', inplace=True)
drop_baku.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5244 entries, 0 to 5648
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   slang   5244 non-null   object
#  1   baku    5243 non-null   object
#  2   source  5244 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 163.9+ KB

# %%
drop_baku.to_csv('baku.csv', index=False)
